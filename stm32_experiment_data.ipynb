# %%
# %load_ext autoreload
# %autoreload 2

from utility import *
import glob

# Use glob to get all .npy files in the directory
recording_dir = "recording"
file_list = sorted(glob.glob(os.path.join(recording_dir, "*.npy")))

# Call the function
total_sum = combine_histogram(file_list)
save_histogram_to_h5("./experimentData.h5",total_sum,range_min=800,range_max=2150)
display_image_from_h5("./experimentData.h5")
# Out:
# [INFO] Summed 1000 histograms with shape (8, 8, 18)
